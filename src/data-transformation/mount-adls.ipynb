# %%
# Mount ADLS Gen2
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": "6a8451c1-a6d1-47b4-8e9f-f32a56d04194",
    "fs.azure.account.oauth2.client.secret": "HRG8Q~2XrJtftukFh4eZ51KOiHuga9pAlMBwWa_Q",
    "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/5d7b49e9-50d2-40dc-bab1-14a2d903542c/oauth2/token"
}

# Mount bronze
dbutils.fs.mount(
    source="abfss://creditrisk-data@creditrisk.dfs.core.windows.net/bronze",
    mount_point="/mnt/creditrisk/bronze",
    extra_configs=configs
)

# Mount silver
dbutils.fs.mount(
    source="abfss://creditrisk-data@creditrisk.dfs.core.windows.net/silver",
    mount_point="/mnt/creditrisk/silver",
    extra_configs=configs
)

# Mount gold
dbutils.fs.mount(
    source="abfss://creditrisk-data@creditrisk.dfs.core.windows.net/gold",
    mount_point="/mnt/creditrisk/gold",
    extra_configs=configs
)
# Out:
# True

# %%
display(dbutils.fs.mounts())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(dbutils.fs.ls("/mnt/creditrisk/bronze"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
